# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/furkankumrudev/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# **Task Type: Ranking / Scoring**
# **Why:** Our decision is "Which page should an editor fix first?". We are not just predicting a binary decline (Classification); we need to build a prioritized queue of content items sorted by their potential for recovery. This requires scoring each page relative to others so human effort is directed to the top of the queue.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# **Target:** `target_underperforming` (A binary proxy label).
# **Source:** Observed outcome. We define a page as underperforming if it has high visibility (high total_impressions) but a very low click-through rate (CTR). The model will output a continuous priority score to rank these items, aiming to place the truly underperforming pages at the top of the queue.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# **Success Metric: Precision@K (e.g., Precision@100)**
# **What means 'good':** Since an editor can only fix a limited number of pages per week, we only care about the top of the ranked list. If our Precision@100 is > 0.80, it means 80 of the first 100 pages the model recommends are genuinely underperforming pages that need human attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Baseline metric setup placeholder
from sklearn.metrics import precision_score, roc_auc_score
# print("Baseline Metric Check Ready")

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# **Unit of Analysis: One row = One specific content item (pseudonymized page).**
# Below is a real slice of the data. Each row represents a single page's performance over a trailing 90-day window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

try:
    # Load the real dataset
    df = pd.read_csv('data/raw/content_refresh_anonymized.csv')

    # Calculate a simple proxy target for demonstration
    df['target_underperforming'] = ((df['impressions_90d'] > 500) & (df['ctr'] < 0.015)).astype(int)

    print(f"Unit of analysis check. Total rows (content items): {len(df)}")
    display(df[['content_id', 'client_id', 'impressions_90d', 'ctr', 'target_underperforming']].head(5))
except FileNotFoundError:
    print("Dataset not found. Please verify 'data/raw/content_refresh_anonymized.csv' exists.")
# Out:
# Unit of analysis check. Total rows (content items): 30000
#              content_id          client_id  impressions_90d   ctr  \
# 0  content_304f48230142  client_f369cb89fc             3803  0.76
# 1  content_a1fb4e703a9e  client_4e07408562            15320  0.05
# 2  content_9aa793d4d895  client_7f2253d7e2            12581  0.09
# 3  content_331d6c4de07b  client_19581e27de            11751  0.49
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140  0.13
#
#    target_underperforming
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# **Why ML beats an if-statement:**
# A simple rule like `if impressions > 1000 and ctr < 0.01` is rigid. It fails to account for the content type, the historical trend percentage, keyword volatility, and the site's overall baseline. Machine learning can weigh these tangled, shifting signals together to calculate a nuanced priority score, rather than a hard binary cut-off.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
